# %% [markdown]
# ### В этом Notebook:
#
# Мы попрактикуемся решать разные задачи и закрепим пройденные знания по всему блоку.

# %%
# Выполни прежде чем проходить Notebook
from google.colab import drive
import os
drive.mount ('/content/gdrive', force_remount=True)

# %run /content/gdrive/MyDrive/02_NumPy_and_Pandas/0_package_installation.ipynb
# Перезагрузка ядра
os.kill(os.getpid(), 9)
# Out:
# Mounted at /content/gdrive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 121.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 40.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 9.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: matplotlib
# ...

# %% [markdown]
# ### Задача 1.
# Вам дан одномерный массив из 11 элементов от 0 до 10 цифр. Вам необходимо отфильтровать массив так, чтобы получить массив [4 5 6 7]

# %%
import numpy as np
Z = np.arange(11)
# Напишите свое решение ниже
# Out:
# [4 5 6 7]

# %% [markdown]
# ### Задача 2
# Создать вектор размера 10, заполненный нулями, но пятый элемент равен 1.

# %%
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 3
# Разверните вектор, первый элемент становится последним.

# %%
Z_1 = np.arange(50)
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 4
# Создать массив 10x10 со случайными значениями, найдите минимум и максимум.

# %%
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 5
# Как получить минимальное значение, 25 перцентиль, медиану, 75 перцентиль и максимальное значение в серии Pandas?

# %%
import pandas as pd
ser = pd.Series(np.random.normal(10, 5, 25))
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 6
#
# Как посчитать кол-во уникальных значений в серии Pandas?

# %%
ser = pd.Series(np.take(list('abcdefgh'), np.random.randint(8, size=30)))
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 7
# Как проверить есть ли в датафрейме хотя бы одно пропущенное значение (NaN)?

# %%
import pandas as pd
import numpy as np
data = {'col_1': [3, 2, 1, np.NaN], 'col_2': ['a', 'b','c', 'd']}
df = pd.DataFrame.from_dict(data)
# Напишите свое решение ниже
# Out:
#    col_1 col_2
# 0    3.0     a
# 1    2.0     b
# 2    1.0     c
# 3    NaN     d

# %% [markdown]
# ### Задача 8
# Получите все строки за 2018-03-25, в качестве столбцов выведите AveragePrice, Total Volume, type, year, region.

# %%
import pandas as pd
avacod_df = pd.read_csv("/content/gdrive/MyDrive/02_NumPy_and_Pandas/Data/avocado.csv", index_col='Date')
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 9
# Посчитайте среднюю цену, максимальный рейтинг в разрезе каждого фрукта.
# Переименуйте полученные после агрегации столбцы price в mean_price, rating в max_rating.

# %%
df = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                   'rating': np.random.rand(9),
                   'price': np.random.randint(0, 15, 9)})
# Напишите свое решение ниже

# %% [markdown]
# ### Задача 10
# Как соединить два датафрейма ниже, используя ключ из двух колонок?

# %%
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})

df2 = pd.DataFrame({'pazham': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})
# Напишите свое решение ниже
# В качестве ключей использовать fruit, weight и pazham, kilo соотвественно
